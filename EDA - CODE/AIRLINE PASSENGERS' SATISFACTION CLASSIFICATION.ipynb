# %% [markdown]
# # AIRLINE PASSENGERS SATISFACTION CLASSIFICATION

# %% [markdown]
# #### IMPORTING LIBRARIES

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# #### INJESTING THE DATA IN NOTEBOOK

# %%
data = pd.read_csv('airline_passenger_satisfaction.csv')

# %% [markdown]
# #### GETTING ACQUAINTED WITH THE COLUMN ATTRIBUTES

# %%
data.head()
# Out:
#    ID  Gender  Age Customer Type Type of Travel     Class  Flight Distance  \
# 0   1    Male   48    First-time       Business  Business              821
# 1   2  Female   35     Returning       Business  Business              821
# 2   3    Male   41     Returning       Business  Business              853
# 3   4    Male   50     Returning       Business  Business             1905
# 4   5  Female   49     Returning       Business  Business             3470
#
#    Departure Delay  Arrival Delay  Departure and Arrival Time Convenience  \
# 0                2            5.0                                       3
# 1               26           39.0                                       2
# 2                0            0.0                                       4
# 3                0            0.0                                       2
# 4                0            1.0                                       3
#
# ...

# %% [markdown]
# #### ROWS vs COLUMNS

# %%
data.shape
# Out:
# (129880, 24)

# %% [markdown]
# #### UNDERSTANDING THE DESCRIPTION OF DATA IN THE DataFrame

# %%
data.describe()
# Out:
#                   ID            Age  Flight Distance  Departure Delay  \
# count  129880.000000  129880.000000    129880.000000    129880.000000
# mean    64940.500000      39.427957      1190.316392        14.713713
# std     37493.270818      15.119360       997.452477        38.071126
# min         1.000000       7.000000        31.000000         0.000000
# 25%     32470.750000      27.000000       414.000000         0.000000
# 50%     64940.500000      40.000000       844.000000         0.000000
# 75%     97410.250000      51.000000      1744.000000        12.000000
# max    129880.000000      85.000000      4983.000000      1592.000000
#
#        Arrival Delay  Departure and Arrival Time Convenience  \
# count  129487.000000                           129880.000000
# mean       15.091129                                3.057599
# std        38.465650                                1.526741
# min         0.000000                                0.000000
# ...

# %% [markdown]
# #### INFORMATION OF EVERY COLUMN ATTRIBUTES

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 129880 entries, 0 to 129879
# Data columns (total 24 columns):
#  #   Column                                  Non-Null Count   Dtype
# ---  ------                                  --------------   -----
#  0   ID                                      129880 non-null  int64
#  1   Gender                                  129880 non-null  object
#  2   Age                                     129880 non-null  int64
#  3   Customer Type                           129880 non-null  object
#  4   Type of Travel                          129880 non-null  object
#  5   Class                                   129880 non-null  object
#  6   Flight Distance                         129880 non-null  int64
#  7   Departure Delay                         129880 non-null  int64
#  8   Arrival Delay                           129487 non-null  float64
#  9   Departure and Arrival Time Convenience  129880 non-null  int64
# ...

# %% [markdown]
# ## EXPLORING DATA

# %%
sns.histplot(data.Satisfaction)
# Out:
# <AxesSubplot:xlabel='Satisfaction', ylabel='Count'>

# %% [markdown]
# #### COMPARING COUNT OF SATISFIED PERSONS BASED ON DIFFERENT FEATURES

# %%
sns.set_palette("husl")
for col in data.columns:
    if data[col].dtype != 'object':
        sns.barplot(data=data, x="Satisfaction", y=col)
        plt.show()

# %%
data["Age"].describe()
# Out:
# count    129880.000000
# mean         39.427957
# std          15.119360
# min           7.000000
# 25%          27.000000
# 50%          40.000000
# 75%          51.000000
# max          85.000000
# Name: Age, dtype: float64

# %%
sns.set_palette("Set3")
sns.histplot(data=data, x="Age")
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Count'>

# %% [markdown]
# ##### GROUPING AS Young Age Group [age less than 20]

# %%
young_group = data[data["Age"] < 20].groupby(["Satisfaction"]).count()["ID"]
young_group.plot(kind="bar")
# Out:
# <AxesSubplot:xlabel='Satisfaction'>

# %% [markdown]
# ##### GROUPING AS Middle Age Group [ age between 20 to 65]

# %%
middle_age_group = data[data["Age"] > 20][(data["Age"] < 65)].groupby(["Satisfaction"]).count()["ID"]
middle_age_group.plot(kind="bar")
# Out:
# C:\Users\ChaturV\AppData\Local\Temp/ipykernel_7020/2934392660.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   middle_age_group = data[data["Age"] > 20][(data["Age"] < 65)].groupby(["Satisfaction"]).count()["ID"]
# <AxesSubplot:xlabel='Satisfaction'>

# %% [markdown]
# ##### GROUPING AS Old Age Group [ age above 65]

# %%
old_persons = data[data["Age"] > 65].groupby(["Satisfaction"]).count()["ID"]
old_persons.plot(kind = "bar")
# Out:
# <AxesSubplot:xlabel='Satisfaction'>

# %%
data.groupby(["Satisfaction"]).count()["Food and Drink"]
# Out:
# Satisfaction
# Neutral or Dissatisfied    73452
# Satisfied                  56428
# Name: Food and Drink, dtype: int64

# %% [markdown]
# #### GROUPING SATISFACTION with FOOD and DRINK RATING

# %%
food_group = data.groupby(["Satisfaction" , "Food and Drink"]).count()["ID"]
food_group
# Out:
# Satisfaction             Food and Drink
# Neutral or Dissatisfied  0                    77
#                          1                 12848
#                          2                 16731
#                          3                 16748
#                          4                 14492
#                          5                 12556
# Satisfied                0                    55
#                          1                  3203
#                          2                 10652
#                          3                 11046
#                          4                 16071
#                          5                 15401
# Name: ID, dtype: int64

# %%
data["Food and Drink"][data["Satisfaction"] == "Neutral or Dissatisfied"][data["Food and Drink"] <= 3].count()
# Out:
# 46404

# %%
seat_group = data.groupby(["Satisfaction","Seat Comfort"]).count()["ID"]

# %%
data["Food and Drink"][data["Satisfaction"] == "Neutral or Dissatisfied"][data["Food and Drink"] > 3].count()
# Out:
# 27048

# %%
sns.set_palette("PuBuGn_d")
food_group.plot(kind="bar")
# Out:
# <AxesSubplot:xlabel='Satisfaction,Food and Drink'>

# %% [markdown]
# #### CHECK the Impact of the Seat Comfort on the satisfactionn of the Customer

# %%
data.groupby(["Satisfaction"]).count()["Seat Comfort"]
# Out:
# Satisfaction
# Neutral or Dissatisfied    73452
# Satisfied                  56428
# Name: Seat Comfort, dtype: int64

# %%
data.groupby(["Satisfaction","Seat Comfort"]).count()["ID"]
# Out:
# Satisfaction             Seat Comfort
# Neutral or Dissatisfied  0                   1
#                          1               11734
#                          2               14341
#                          3               18334
#                          4               17481
#                          5               11561
# Satisfied                1                3374
#                          2                4188
#                          3                4994
#                          4               22275
#                          5               21597
# Name: ID, dtype: int64

# %% [markdown]
# Check the number of customers that were unsatisfied and seat comfort rating below 3

# %%
data["Seat Comfort"][data["Satisfaction"] == "Neutral or Dissatisfied"][data["Seat Comfort"] <= 3].count()
# Out:
# 44410

# %%
data["Seat Comfort"][data["Satisfaction"] == "Neutral or Dissatisfied"][data["Seat Comfort"] > 3].count()
# Out:
# 29042

# %%
seat_group.plot(kind="bar")
# Out:
# <AxesSubplot:xlabel='Satisfaction,Seat Comfort'>

# %% [markdown]
# ## DATA PREPROCESSING

# %% [markdown]
# ##### Identifying and handling the missing values

# %%
data.isnull().sum()
# Out:
# ID                                        0
# Gender                                    0
# Age                                       0
# Customer Type                             0
# Type of Travel                            0
# Class                                     0
# Flight Distance                           0
# Departure Delay                           0
# Arrival Delay                             0
# Departure and Arrival Time Convenience    0
# Ease of Online Booking                    0
# Check-in Service                          0
# Online Boarding                           0
# Gate Location                             0
# On-board Service                          0
# Seat Comfort                              0
# Leg Room Service                          0
# Cleanliness                               0
# Food and Drink                            0
# In-flight Service                         0
# In-flight Wifi Service                    0
# ...

# %% [markdown]
# ##### Check %age of null values in arrival delay

# %%
data["Arrival Delay"].isnull().sum()*100/data["Arrival Delay"].count()
# Out:
# 0.30350537119556403

# %%
data["Arrival Delay"].value_counts()
# Out:
# 0.0       72753
# 1.0        2747
# 2.0        2587
# 3.0        2442
# 4.0        2373
#           ...
# 1011.0        1
# 386.0         1
# 624.0         1
# 355.0         1
# 412.0         1
# Name: Arrival Delay, Length: 472, dtype: int64

# %%
data["Arrival Delay"].describe()
# Out:
# count    129487.000000
# mean         15.091129
# std          38.465650
# min           0.000000
# 25%           0.000000
# 50%           0.000000
# 75%          13.000000
# max        1584.000000
# Name: Arrival Delay, dtype: float64

# %% [markdown]
# ##### Plot the data before filling null

# %%
sns.set_palette("husl")
sns.displot(data=data, x="Arrival Delay", kind="kde")

# %% [markdown]
# ##### FILLING THE NULLS

# %%
data["Arrival Delay"] = data["Arrival Delay"].fillna(data["Arrival Delay"].mean())

# %%
sns.set_palette("husl")
sns.displot(data=data, x="Arrival Delay", kind="kde")

# %% [markdown]
# ### IDENTIFYING AND HANDLING THE OUTLIERS

# %% [markdown]
# ##### PLOTTING BOX PLOT & SCATTER PLOT (FLIGHT DISTANCE vs SATISFACTION)

# %%
sns.set_palette("Set3")
bp = sns.boxplot(data=data, x="Flight Distance")
plt.show()
sp = sns.scatterplot(data=data, x="Flight Distance", y=data["Satisfaction"])
plt.show()

# %% [markdown]
# ##### IDENTIFYING THE INTERQUARTILE RANGE (IQR) & DROPPING THE OUTLIERS

# %%
Q1_fd = data['Flight Distance'].quantile(0.25)
Q3_fd = data['Flight Distance'].quantile(0.75)
IQR_fd = Q3_fd - Q1_fd
UB_fd = Q3_fd + 1.8*(IQR_fd)
data.drop(data[data['Flight Distance']>UB_fd].index, axis=0, inplace=True)

# %%
bp = sns.boxplot(data = data, x = "Flight Distance")
plt.show()
sp = sns.scatterplot(data = data, x = "Flight Distance", y=data["Satisfaction"])
plt.show()

# %% [markdown]
# ##### PLOTTING BOX PLOT & SCATTER PLOT (DEPARTURE DELAY vs SATISFACTION)

# %%
bp = sns.boxplot(data=data, x="Departure Delay")
plt.show()
bp = sns.scatterplot(data=data, x="Departure Delay", y=data["Satisfaction"])
plt.show()

# %% [markdown]
# ##### REMOVING OUTLIER

# %%
#removing outlier
data.drop(data[data['Departure Delay']>550].index, axis=0, inplace=True)

# %%
bp = sns.boxplot(data=data, x="Departure Delay")
plt.show()
bp = sns.scatterplot(data=data, x="Departure Delay", y=data["Satisfaction"])
plt.show()

# %% [markdown]
# ##### PLOTTING BOX PLOT & SCATTER PLOT (ARRIVAL DELAY vs SATISFACTION)

# %%
bp = sns.boxplot(data=data, x="Arrival Delay")
plt.show()
bp = sns.boxplot(data=data, x="Arrival Delay", y=data["Satisfaction"])
plt.show()

# %% [markdown]
# ##### REMOVING OUTLIER

# %%
data.drop(data[data['Arrival Delay']>500].index, axis = 0, inplace =True)

# %%
bp = sns.boxplot(data = data, x='Arrival Delay')
plt.show()
bp = sns.scatterplot(data = data, x='Arrival Delay', y='Satisfaction')
plt.show()

# %% [markdown]
# #### COUNTING THE CATEGORIES FOR EVERY COLUMN

# %%
sns.set_palette("cubehelix")
for col in ['Gender','Customer Type','Type of Travel','Class','Departure and Arrival Time Convenience',
           'Ease of Online Booking','Check-in Service','Online Boarding','Gate Location','On-board Service', 'Seat Comfort', 'Leg Room Service', 'Cleanliness',
       'Food and Drink', 'In-flight Service', 'In-flight Wifi Service',
       'In-flight Entertainment', 'Baggage Handling']:
    sns.countplot(data[col])
    plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# ...

# %%
data['Type of Travel'].value_counts()
# Out:
# Business    89611
# Personal    40150
# Name: Type of Travel, dtype: int64

# %%
sns.countplot(data['Type of Travel'])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Type of Travel', ylabel='count'>

# %% [markdown]
# Resample the data using upsampling to solve the imbalance data problem

# %%
sns.countplot(data['Type of Travel'])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Type of Travel', ylabel='count'>

# %% [markdown]
# ### CUSTOMER TYPE PROBLEM

# %%
data['Customer Type'].value_counts()
# Out:
# Returning     155270
# First-time     24034
# Name: Customer Type, dtype: int64

# %%
sns.countplot(data['Customer Type'])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Customer Type', ylabel='count'>

# %% [markdown]
# ### After understanding the count of categorical data, we need to do undersampling and oversampling since the difference between the categories is huge to provide us a bias result.
